# %% [markdown]
# <a href="https://colab.research.google.com/github/sana-123-githu/internship/blob/main/sub_plots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
plt.style.use('dark_background')
import numpy as np

#Days (X-axis)
days=np.arange(7) #Days 0-6

#Sample stock prices

apple = [150,152,153,151,155,157,156]
google = [2800,2820,2810,2830,2840,2850,2860]
amazon = [3400,3420,3410,3430,3440,3450,3460]
microsoft = [299,301,300,302,303,305,304]

fig,axs = plt.subplots(2,2,figsize=(10,8))

axs[0,0].plot(days,apple,marker='o',color='red')
axs[0,0].set_title("Apple Stock price")
axs[0,0].grid(True)

axs[0,1].plot(days,google,marker='s',color='blue')
axs[0,1].set_title("Google Stock price")
axs[0,1].grid(True)

axs[1,0].plot(days,amazon,marker='d',color='green')
axs[1,0].set_title("Amazon Stock price")
axs[1,0].grid(True)

axs[1,1].plot(days,microsoft,marker='*',color='yellow')
axs[1,1].set_title("microsoft Stock price")
axs[1,1].grid(True)

for ax in axs[1,:]:
    ax.set_xlabel("Day")
for ax in axs[:,0]:
    ax.set_ylabel("price($)")
plt.tight_layout()
plt.show()
